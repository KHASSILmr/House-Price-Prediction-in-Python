# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ### Loading data set

# %%
data = pd.read_csv('housing.csv')

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %% [markdown]
# ### Data Exploration

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20433 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

X = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2915     -119.06     35.36                 9.0       1228.0           234.0
# 12163    -117.16     33.76                11.0       4934.0           929.0
# 6296     -117.91     34.02                17.0       5973.0          1384.0
# 6389     -118.03     34.16                39.0       2731.0           366.0
# 5393     -118.37     34.04                42.0       1809.0           424.0
# ...          ...       ...                 ...          ...             ...
# 20570    -121.96     38.54                 6.0       1485.0           318.0
# 9364     -122.54     37.94                39.0       3670.0           775.0
# 7735     -118.13     33.93                34.0       2122.0           517.0
# 18003    -121.99     37.27                27.0       2937.0           497.0
# 14316    -117.14     32.70                36.0        633.0           148.0
#
#        population  households  median_income ocean_proximity
# 2915        409.0       212.0         4.3482          INLAND
# 12163      2508.0       840.0         2.6250          INLAND
# 6296       4349.0      1229.0         3.2799       <1H OCEAN
# 6389       1034.0       338.0         9.8098          INLAND
# 5393       1094.0       382.0         2.7670       <1H OCEAN
# ...           ...         ...            ...             ...
# 20570       894.0       308.0         3.2222          INLAND
# 9364       1519.0       788.0         4.4081        NEAR BAY
# 7735       1578.0       488.0         3.1496       <1H OCEAN
# 18003      1454.0       511.0         5.4051       <1H OCEAN
# 14316       557.0       139.0         1.5729      NEAR OCEAN
#
# [16346 rows x 9 columns]

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2915     -119.06     35.36                 9.0       1228.0           234.0
# 12163    -117.16     33.76                11.0       4934.0           929.0
# 6296     -117.91     34.02                17.0       5973.0          1384.0
# 6389     -118.03     34.16                39.0       2731.0           366.0
# 5393     -118.37     34.04                42.0       1809.0           424.0
# ...          ...       ...                 ...          ...             ...
# 20570    -121.96     38.54                 6.0       1485.0           318.0
# 9364     -122.54     37.94                39.0       3670.0           775.0
# 7735     -118.13     33.93                34.0       2122.0           517.0
# 18003    -121.99     37.27                27.0       2937.0           497.0
# 14316    -117.14     32.70                36.0        633.0           148.0
#
#        population  households  median_income ocean_proximity  \
# 2915        409.0       212.0         4.3482          INLAND
# 12163      2508.0       840.0         2.6250          INLAND
# 6296       4349.0      1229.0         3.2799       <1H OCEAN
# 6389       1034.0       338.0         9.8098          INLAND
# 5393       1094.0       382.0         2.7670       <1H OCEAN
# ...           ...         ...            ...             ...
# 20570       894.0       308.0         3.2222          INLAND
# 9364       1519.0       788.0         4.4081        NEAR BAY
# 7735       1578.0       488.0         3.1496       <1H OCEAN
# 18003      1454.0       511.0         5.4051       <1H OCEAN
# 14316       557.0       139.0         1.5729      NEAR OCEAN
#
#        median_house_value
# 2915              95200.0
# 12163            155400.0
# 6296             199300.0
# 6389             500001.0
# 5393             143000.0
# ...                   ...
# 20570            139600.0
# 9364             435200.0
# 7735             191900.0
# 18003            273500.0
# 14316             82700.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(numeric_only=True), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# ### Data Preprocessing

# %%
train_data["total_rooms"] = np.log(train_data["total_rooms"] + 1)
train_data["total_bedrooms"] = np.log(train_data["total_bedrooms"] + 1)
train_data["population"] = np.log(train_data["population"] + 1)
train_data["households"] = np.log(train_data["households"] + 1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7221
# INLAND        5207
# NEAR OCEAN    2099
# NEAR BAY      1815
# ISLAND           4
# Name: count, dtype: int64

# %%
pd.get_dummies(train_data.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 2915       False    True   False     False       False
# 12163      False    True   False     False       False
# 6296        True   False   False     False       False
# 6389       False    True   False     False       False
# 5393        True   False   False     False       False
# ...          ...     ...     ...       ...         ...
# 20570      False    True   False     False       False
# 9364       False   False   False      True       False
# 7735        True   False   False     False       False
# 18003       True   False   False     False       False
# 14316      False   False   False     False        True
#
# [16346 rows x 5 columns]

# %%
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop('ocean_proximity', axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2915     -119.06     35.36                 9.0     7.113956        5.459586
# 12163    -117.16     33.76                11.0     8.504108        6.835185
# 6296     -117.91     34.02                17.0     8.695172        7.233455
# 6389     -118.03     34.16                39.0     7.912789        5.905362
# 5393     -118.37     34.04                42.0     7.501082        6.052089
# ...          ...       ...                 ...          ...             ...
# 20570    -121.96     38.54                 6.0     7.303843        5.765191
# 9364     -122.54     37.94                39.0     8.208219        6.654153
# 7735     -118.13     33.93                34.0     7.660585        6.249975
# 18003    -121.99     37.27                27.0     7.985484        6.210600
# 14316    -117.14     32.70                36.0     6.452049        5.003946
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 2915     6.016157    5.361292         4.3482             95200.0      False
# 12163    7.827640    6.734592         2.6250            155400.0      False
# 6296     8.377931    7.114769         3.2799            199300.0       True
# 6389     6.942157    5.826000         9.8098            500001.0      False
# 5393     6.998510    5.948035         2.7670            143000.0       True
# ...           ...         ...            ...                 ...        ...
# 20570    6.796824    5.733341         3.2222            139600.0      False
# 9364     7.326466    6.670766         4.4081            435200.0      False
# 7735     7.364547    6.192362         3.1496            191900.0       True
# 18003    7.282761    6.238325         5.4051            273500.0       True
# 14316    6.324359    4.941642         1.5729             82700.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 2915     True   False     False       False
# 12163    True   False     False       False
# 6296    False   False     False       False
# 6389     True   False     False       False
# 5393    False   False     False       False
# ...       ...     ...       ...         ...
# 20570    True   False     False       False
# 9364    False   False      True       False
# 7735    False   False     False       False
# 18003   False   False     False       False
# 14316   False   False     False        True
#
# [16346 rows x 14 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude", y="longitude", hue="median_house_value", data=train_data, palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %% [markdown]
# ### Feature Engineering

# %%
train_data["bedroom_ratio"] = train_data["total_bedrooms"] / train_data["total_rooms"]
train_data["household_rooms"] = train_data["total_rooms"] / train_data["households"]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# ### Lineair Regression Model

# %%
from sklearn.linear_model import LinearRegression

X_train , y_train = train_data.drop('median_house_value', axis=1), train_data['median_house_value']

reg = LinearRegression()

reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
test_data = X_test.join(y_test)

test_data["total_rooms"] = np.log(test_data["total_rooms"] + 1)
test_data["total_bedrooms"] = np.log(test_data["total_bedrooms"] + 1)
test_data["population"] = np.log(test_data["population"] + 1)
test_data["households"] = np.log(test_data["households"] + 1)

test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop('ocean_proximity', axis=1)

test_data["bedroom_ratio"] = test_data["total_bedrooms"] / test_data["total_rooms"]
test_data["household_rooms"] = test_data["total_rooms"] / test_data["households"]

X_test , y_test = test_data.drop('median_house_value', axis=1), test_data['median_house_value']

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5339     -118.45     34.03                45.0     6.590301        5.129899
# 7718     -118.13     33.95                24.0     8.804325        7.524561
# 1439     -122.01     37.97                32.0     8.010692        6.269096
# 13900    -116.51     34.45                21.0     9.048174        7.876638
# 11340    -117.93     33.75                24.0     7.230563        5.828946
# ...          ...       ...                 ...          ...             ...
# 2594     -124.06     40.88                12.0     7.643962        6.052089
# 2349     -119.67     36.80                 9.0     8.219595        6.232448
# 5562     -118.28     33.91                41.0     6.431331        4.897840
# 18002    -121.98     37.28                27.0     8.168203        6.380123
# 9832     -121.93     36.63                33.0     7.462215        5.837730
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 5339     6.255750    5.170484         2.6528            300000.0       True
# 7718     8.240913    7.459339         3.1104            230000.0       True
# 1439     7.161622    6.240276         3.6449            211500.0      False
# 13900    7.754053    6.899723         1.3811             51300.0      False
# 11340    7.295056    5.720312         4.2219            162800.0       True
# ...           ...         ...            ...                 ...        ...
# 2594     7.380256    6.084499         2.5667            139500.0      False
# 2349     7.398174    6.163315         6.0110            163100.0      False
# 5562     6.466145    5.093750         2.6546            159600.0       True
# 18002    7.453562    6.317165         5.7812            275000.0       True
# 9832     6.459904    5.799093         3.1912            319800.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 5339    False   False     False       False       0.778401         1.274600
# 7718    False   False     False       False       0.854644         1.180309
# 1439    False   False      True       False       0.782591         1.283708
# 13900    True   False     False       False       0.870522         1.311382
# 11340   False   False     False       False       0.806154         1.264016
# ...       ...     ...       ...         ...            ...              ...
# 2594    False   False     False        True       0.791748         1.256301
# 2349     True   False     False       False       0.758243         1.333632
# 5562    False   False     False       False       0.761559         1.262593
# 18002   False   False     False       False       0.781093         1.293017
# 9832    False   False     False        True       0.782305         1.286790
#
# [4087 rows x 16 columns]

# %%
reg.score(X_train, y_train)
# Out:
# 0.6699978211762987

# %%
reg.score(X_test, y_test)
# Out:
# 0.6746437041803195

# %% [markdown]
# ### Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_train, y_train)
# Out:
# 0.973411058643122

# %%
forest.score(X_test, y_test)
# Out:
# 0.8274253133888627

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [50, 100, 200], 
    'max_features': [None, 0.1, 0.2, 0.3, 0.5, 0.7,]
}

grid_search = GridSearchCV(estimator=forest,
                            param_grid=param_grid, scoring="neg_mean_squared_error",
                            return_train_score=True, cv=5)

grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [None, 0.1, 0.2, 0.3, 0.5, 0.7],
#                          'n_estimators': [50, 100, 200]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(max_features=0.7, n_estimators=200)

# %%
grid_search.best_params_
# Out:
# {'max_features': 0.7, 'n_estimators': 200}

# %%
grid_search.best_estimator_.score(X_train, y_train)
# Out:
# 0.9746415049671238

# %%
grid_search.best_estimator_.score(X_test, y_test)
# Out:
# 0.8309883886336393
